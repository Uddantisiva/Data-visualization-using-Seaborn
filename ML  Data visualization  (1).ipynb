# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("insurance.csv")

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# # what is the data types of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # how does the data is look like?

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df.sample(5)
# Out:
#       age     sex    bmi  children smoker     region      charges
# 661    57  female  23.98         1     no  southeast  22192.43711
# 1334   18  female  31.92         0     no  northeast   2205.98080
# 573    62  female  36.86         1     no  northeast  31620.00106
# 864    51    male  25.40         0     no  southwest   8782.46900
# 515    58    male  35.70         0     no  southwest  11362.75500

# %% [markdown]
# # Are there any missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # How does the data look mathematically

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Are there duplicate values

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# # How is the Correlation b/w Coloumns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # EDA -  Data Analysis

# %%
df["smoker"].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# # 1.Categorical data

# %%
import seaborn as sns 
import numpy as np

# %%
sns.countplot(x=df["smoker"])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
df["smoker"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='smoker'>

# %%
df["smoker"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical data

# %% [markdown]
# #                histogram

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(x=df["smoker"])
df.info()
# sns.histplot(x=df["children"])
# sns.histplot(x=df["sex"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.distplot(df["charges"])
# Out:
# C:\Users\sivau\AppData\Local\Temp\ipykernel_29916\3454039009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["charges"])
# <Axes: xlabel='charges', ylabel='Density'>

# %% [markdown]
# # Box plot

# %%
sns.boxplot(df["charges"])
# Out:
# <Axes: >

# %%
df["charges"].describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %% [markdown]
# # Scatter plot (Numerical -Numerical)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.scatterplot(x = df["bmi"],y = df["charges"],hue=df["sex"])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# # numeric - categorical

# %% [markdown]
# # Bar plot

# %%
df.sample(2)
# Out:
#      age     sex    bmi  children smoker     region    charges
# 399   18  female  38.17         0     no  southeast  1631.6683
# 684   33  female  18.50         1     no  southwest  4766.0220

# %%
sns.barplot(x=df["sex"],y=df["charges"])
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x=df["children"],y=df["charges"])
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %% [markdown]
# # Distplot

# %%
sns.distplot(df[df["sex"]=="female"]["charges"],hist=False)
sns.distplot(df[df["sex"]=="male"]["charges"],hist=False)
# Out:
# C:\Users\sivau\AppData\Local\Temp\ipykernel_29916\2013125340.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["sex"]=="female"]["charges"],hist=False)
# C:\Users\sivau\AppData\Local\Temp\ipykernel_29916\2013125340.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # categoricla - categorical

# %% [markdown]
# # Heat map

# %%
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
cross=pd.crosstab(df["children"],df["smoker"])
cross
# Out:
# smoker     no  yes
# children
# 0         459  115
# 1         263   61
# 2         185   55
# 3         118   39
# 4          22    3
# 5          17    1

# %%
sns.heatmap(cross)
# Out:
# <Axes: xlabel='smoker', ylabel='children'>

# %% [markdown]
# # cluster map

# %%
 sns.clustermap(cross)

# %%
sns.pairplot(df,hue="sex")
# Out:
# C:\Users\sivau\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # Line plot(numeric - Numeric repre

# %%
flight=sns.load_dataset("flights")

# %%
flight.head(2)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118

# %%
new=flight.pivot_table(values="passengers",index="month",columns="year")

# %%
new.shape
# Out:
# (12, 12)

# %%
sns.heatmap(new)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(new)
